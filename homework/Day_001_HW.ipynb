# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估
#
#
# 我選的資料是competitor裡面的LANL Earthquake Prediction
# 網址如下https://www.kaggle.com/c/LANL-Earthquake-Prediction
#
# 1.我認為這組資料重要的原因在於，地震對人類來說仍然是屬於不可預測得一種自然災害，而且大型地震的損害程度甚至超出我們可以承擔的範圍，
# 因此我認為去蒐集資料來研究如何預測地震會是一個實用而且會有很大貢獻的題目
#
# 2.這組競賽裡面的training資料由參賽單位提供，
#
# 3.資料型態為地震時間 地震大小 地震位置 以文字記錄
#
# 5.https://www.kaggle.com/artgor/earthquakes-fe-more-features-and-samples
# 這組參賽者是利用kfold的方式增加samples 和features去預測

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#  假設載客地點和載客的時間有一定的分布
#  例如說在車站附近較容易有載客量，觀光區還有娛樂場所，再來就是不同的地區的載客時間會有不同的巔峰
#  例如說車站遇到假期的時候有較多的客源，凌晨酒吧熱炒店或是夜店，傍晚時候的觀光遊樂區
#  如果可以準確得到分布的話，就可以減少不必要的派車降低成本，也能準確增加司機的載客績效
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 每個時段的載客數據還有地點可以由車隊接單的時候順便做紀錄
# 3. 蒐集而來的資料型態為何
# 我希望載客分布的部份可以由點圖的方式來呈現先了解一個地區最多客源的點在哪裡，然後再用不同的時間去做區分
# 這個地方就可以根據不同的時間去做出每個時段的客源分部然後根據載客量來做成長條的統計
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 驗證的方式就是以每個地區的分部還有時間的收入來做model模擬類似已svm的方式分出最佳時間和載客位置的交集
# 然後一週一次做驗證來找出最好的模組

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    sub = y-yp
    square = sub**2
    mse = MSE = sum(square) / len(y)
    
    return MSE

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 194.305
# The Mean absolute error is 10.930
